# %% [markdown]
# <h1>Legal Citation Classification</h1>

# %% [markdown]
# <h2>Import Required Libraries</h2>

# %%
#Import Required libraries
import re
from lxml import etree
import glob
import os
import time
import nltk.classify
from sklearn.svm import LinearSVC
import nltk
from sklearn.metrics import f1_score, accuracy_score, confusion_matrix
from sklearn.naive_bayes import BernoulliNB, MultinomialNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.neighbors import NearestCentroid
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np
import spacy

# %% [markdown]
# <h2> Function to Correct Errors in XML Files</h2>

# %%
#Define Function to Clean an XML File by substituting all erroneous Characters
# And Fixing the "id=xxx" to id="xxx" so it can be parsed by a XML Parser
def clean_xml(fn):
    print("Processing:", fn)
    file = open(fn, 'r')
    data = file.read()
    file.close()
    data = re.sub("&eacute;", "e", data)
    data = re.sub("&aacute;", "a", data)
    data = re.sub("&yacute;", "y", data)
    data = re.sub("&nbsp;", " ", data)
    data = re.sub("&tm;", "(TM)", data)
    data = re.sub("&reg;", "(R)", data)
    data = re.sub("&agrave;", "a", data)
    data = re.sub("&egrave;", "e", data)
    data = re.sub("&igrave", "i", data)
    data = re.sub("&ecirc;", "e", data)
    data = re.sub("&ocirc;", "o", data)
    data = re.sub("&icirc;", "i", data)
    data = re.sub("&ccedil;", "c", data)
    data = re.sub("&amp;", "and", data)
    data = re.sub("&auml;", "a", data)
    data = re.sub("&szlig;", "ss", data)
    data = re.sub("&aelig;", "e", data)
    data = re.sub("&iuml;", "i", data)
    data = re.sub("&euml;", "e", data)
    data = re.sub("&ouml;", "o", data)
    data = re.sub("&uuml;", "u", data)
    data = re.sub("&acirc;", "a", data)
    data = re.sub("&oslash;", "o", data)
    data = re.sub("&ntilde;", "n", data)
    data = re.sub("&Eacute;", "E", data)
    data = re.sub("&Aring;", "A", data)
    data = re.sub("&Ouml;", "O", data)
    data = re.sub("Ž", "e", data)
    data = re.sub("&#8722;", "", data)
    data = re.sub("&#9679;", "", data)
    data = re.sub("é", "e", data)
    data = re.sub("&#61863;", "", data)
    data = re.sub("&#8356;", "", data)
    data = re.sub("&#283;", "", data)
    data = re.sub("&#8226;", "", data)
    data = re.sub("&#9642;", "", data)
    data = re.sub("&#945;", "", data)
    data = re.sub("&#948;", "", data)
    data = re.sub("ö", "o", data)
    # fix "id=xxx" pattern, causes XML parsing to fail
    
    data = re.sub("\"id=", "id=\"", data)
    file=open(fn,'w')
    file.write(data)
    file.close()

# %% [markdown]
# <h2> Function to Correct Errors in all XML Files in a Directory </h2>

# %%
#This function reads all XML Files from a directory and cleans them one by one 
def clean_dir(dir):
    files = glob.glob("/".join([dir, "*.xml"]))
    for file in files:
        clean_xml(file)

# %% [markdown]
# <h2>Function to Parse a XML File to Extract Labels and Sentences</h2>

# %%
#Parse the Input XML File to Extract the Class Tag as Labels and the text tag as Input Sentences Into an Intermediate File Format
#Note that the Input Sentences are first pre-processed using the Spacy NLP Library to remove all Extraneous Words and 
# reduce the feature vector Size from ~47000 to ~37000
def extract_from_file(file,output_file_handle):
    nlp = spacy.load('en')
    print('==================================================================================================================')
    print('Processing File: ',file)
    parser = etree.XMLParser(recover=True)
    root=etree.parse(file).getroot()
    rootChildren=root.getchildren()
    for rootChild in rootChildren:
        if rootChild.tag=='citations':
            citations=rootChild.getchildren()
            for citation in citations:
                citationChildren=citation.getchildren()
                for citationChild in citationChildren:
                    if citationChild.tag=='class':
                        #print('Class: ',citationChild.text)
                        output_file_handle.write(citationChild.text)
                        output_file_handle.write('\t')
                    if citationChild.tag=='text':
                        #print('Sentence: ',citationChild.text)
                        if citationChild.text is not None:
                            doc = nlp(citationChild.text, disable=['parser', 'ner'])
                            # Only Select the lematized and lower case version of a token if it is not a stop-word, punctuation, currencly Symbol, Bracket, Number , URL, or Email
                            cleaned = [token.lemma_.lower().strip() for token in doc if token.is_punct==False and token.is_stop==False and token.is_bracket==False and token.is_currency==False and token.is_quote==False and token.is_digit==False and len(token)>2 and token.like_url==False and token.like_num==False and token.like_email==False]
                            cleaned_text=' '.join(cleaned)
                            to_write=cleaned_text
                            to_write=re.sub("\n", " ",to_write)
                            output_file_handle.write(to_write)
                            output_file_handle.write('\n')
                        else:
                            output_file_handle.write(" ")
                            output_file_handle.write('\n')

# %% [markdown]
# <h2>Function to Parse All XML Files in a Directory to Extract Labels and Sentences</h2>

# %%
# This function Parses all xml files in a directory and extracts labels and sentences into a txt file
def extract_from_dir(dir,output_file):
    files = glob.glob("/".join([dir, "*.xml"]))
    of=open(output_file,'w')
    for file in files:
        extract_from_file(file,of)
    of.close()

# %% [markdown]
# <h2>Function to Extract Labels and Sentences from Txt File</h2>

# %%
#Return the Label and Sentence from a given input file
def process_line(line):
    """Returns sentence category and sentence in given line"""

    if "\t" in line:
        splits = line.split("\t")
        s_category = splits[0]
        sentence = splits[1].lower()
        #for sw in stopwords:
         #   sentence = sentence.replace(sw, "")
        pattern = re.compile("[^\w']")
        sentence = pattern.sub(' ', sentence)
        sentence = re.sub(' +', ' ', sentence)
        return s_category, sentence
    else:
        splits = line.split(" ")
        s_category = splits[0]
        sentence = line[len(s_category)+1:].lower()
        pattern = re.compile("[^\w']")
        sentence = pattern.sub(' ', sentence)
        sentence = re.sub(' +', ' ', sentence)
        return s_category, sentence

# %% [markdown]
# <h2>Function to Separate Labels and Sentences into Separate Txt Files</h2>

# %%
# Separate Labels and Sentences into Separate Input Files
def create_labels_text_file(input_file, destination_file_data, destination_file_label):
    """Writes training data from given folder into formatted label and data text files"""

    data_file = []
    label_file = []
    
    lines = open(input_file,'r')
    for line in lines:
        c, s = process_line(line)

        data_file.append(s)
        label_file.append(c)

    file = open(destination_file_data,"w")
    for txt in data_file:
        file.write(txt)
        file.write("\n")
    file.close()
    
    file = open(destination_file_label,"w")
    for txt in label_file:
        file.write(txt)
        file.write("\n")
    file.close()

# %% [markdown]
# <h2> Internal Function to Read Sentences from a File Into an Array</h2>

# %%
# Read All lines from a txt file excludin comments
def read_file(path):
    """Reads all lines from file on given path"""

    f = open(path, "r")
    read = f.readlines()
    ret_val = []
    for line in read:
        if line.startswith("#"):
            pass
        else:
            ret_val.append(line)
    return ret_val

# %% [markdown]
# <h2>Function to Plot Confusion Matrix</h2>

# %%
def plot_confusion_matrix(cm,
                          target_names,
                          title='Confusion matrix',
                          cmap=None,
                          normalize=True):
    """
    given a sklearn confusion matrix (cm), make a nice plot

    Arguments
    ---------
    cm:           confusion matrix from sklearn.metrics.confusion_matrix

    target_names: given classification classes such as [0, 1, 2]
                  the class names, for example: ['high', 'medium', 'low']

    title:        the text to display at the top of the matrix

    cmap:         the gradient of the values displayed from matplotlib.pyplot.cm
                  see http://matplotlib.org/examples/color/colormaps_reference.html
                  plt.get_cmap('jet') or plt.cm.Blues

    normalize:    If False, plot the raw numbers
                  If True, plot the proportions

    Usage
    -----
    plot_confusion_matrix(cm           = cm,                  # confusion matrix created by
                                                              # sklearn.metrics.confusion_matrix
                          normalize    = True,                # show proportions
                          target_names = y_labels_vals,       # list of names of the classes
                          title        = best_estimator_name) # title of graph

    Citiation
    ---------
    http://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html

    """
    import matplotlib.pyplot as plt
    import numpy as np
    import itertools

    accuracy = np.trace(cm) / float(np.sum(cm))
    misclass = 1 - accuracy

    if cmap is None:
        cmap = plt.get_cmap('Blues')

    plt.figure(figsize=(8, 6))
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()

    if target_names is not None:
        tick_marks = np.arange(len(target_names))
        plt.xticks(tick_marks, target_names, rotation=45)
        plt.yticks(tick_marks, target_names)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]


    thresh = cm.max() / 1.5 if normalize else cm.max() / 2
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        if normalize:
            plt.text(j, i, "{:0.4f}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")
        else:
            plt.text(j, i, "{:,}".format(cm[i, j]),
                     horizontalalignment="center",
                     color="white" if cm[i, j] > thresh else "black")


    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label\naccuracy={:0.4f}; misclass={:0.4f}'.format(accuracy, misclass))
    plt.show()

# %% [markdown]
# <h2> Correct Errors in All XML Files in the Citations Class Directory</h2>

# %%
#Function Call to Clean all files within the citations_class Directory
clean_dir('corpus/citations_class')
# Out:
# Processing: corpus/citations_class\06_1.xml
# Processing: corpus/citations_class\06_1001.xml
# Processing: corpus/citations_class\06_1004.xml
# Processing: corpus/citations_class\06_1005.xml
# Processing: corpus/citations_class\06_1017.xml
# Processing: corpus/citations_class\06_1019.xml
# Processing: corpus/citations_class\06_102.xml
# Processing: corpus/citations_class\06_1021.xml
# Processing: corpus/citations_class\06_1022.xml
# Processing: corpus/citations_class\06_1023.xml
# Processing: corpus/citations_class\06_1027.xml
# Processing: corpus/citations_class\06_1033.xml
# Processing: corpus/citations_class\06_1041.xml
# Processing: corpus/citations_class\06_1042.xml
# Processing: corpus/citations_class\06_1043.xml
# Processing: corpus/citations_class\06_1044.xml
# Processing: corpus/citations_class\06_1045.xml
# Processing: corpus/citations_class\06_1050.xml
# Processing: corpus/citations_class\06_1054.xml
# Processing: corpus/citations_class\06_106.xml
# Processing: corpus/citations_class\06_1066.xml
# Processing: corpus/citations_class\06_1069.xml
# Processing: corpus/citations_class\06_107.xml
# Processing: corpus/citations_class\06_1071.xml
# Processing: corpus/citations_class\06_1072.xml
# Processing: corpus/citations_class\06_1074.xml
# Processing: corpus/citations_class\06_1077.xml
# Processing: corpus/citations_class\06_1080.xml
# Processing: corpus/citations_class\06_1082.xml
# Processing: corpus/citations_class\06_1083.xml
# Processing: corpus/citations_class\06_1084.xml
# Processing: corpus/citations_class\06_1086.xml
# Processing: corpus/citations_class\06_1088.xml
# Processing: corpus/citations_class\06_1089.xml
# Processing: corpus/citations_class\06_1095.xml
# Processing: corpus/citations_class\06_1096.xml
# Processing: corpus/citations_class\06_11.xml
# Processing: corpus/citations_class\06_1101.xml
# Processing: corpus/citations_class\06_1106.xml
# Processing: corpus/citations_class\06_1107.xml
# Processing: corpus/citations_class\06_111.xml
# Processing: corpus/citations_class\06_1110.xml
# Processing: corpus/citations_class\06_1112.xml
# Processing: corpus/citations_class\06_1113.xml
# Processing: corpus/citations_class\06_1114.xml
# Processing: corpus/citations_class\06_1115.xml
# Processing: corpus/citations_class\06_1117.xml
# Processing: corpus/citations_class\06_1119.xml
# Processing: corpus/citations_class\06_1122.xml
# Processing: corpus/citations_class\06_1129.xml
# Processing: corpus/citations_class\06_1130.xml
# Processing: corpus/citations_class\06_1133.xml
# Processing: corpus/citations_class\06_1138.xml
# Processing: corpus/citations_class\06_1147.xml
# Processing: corpus/citations_class\06_1156.xml
# Processing: corpus/citations_class\06_116.xml
# Processing: corpus/citations_class\06_1163.xml
# Processing: corpus/citations_class\06_1166.xml
# Processing: corpus/citations_class\06_1168.xml
# Processing: corpus/citations_class\06_1169.xml
# Processing: corpus/citations_class\06_1170.xml
# Processing: corpus/citations_class\06_1172.xml
# Processing: corpus/citations_class\06_1173.xml
# Processing: corpus/citations_class\06_1174.xml
# Processing: corpus/citations_class\06_1175.xml
# Processing: corpus/citations_class\06_1176.xml
# Processing: corpus/citations_class\06_1177.xml
# Processing: corpus/citations_class\06_1184.xml
# Processing: corpus/citations_class\06_1186.xml
# Processing: corpus/citations_class\06_1190.xml
# Processing: corpus/citations_class\06_1197.xml
# Processing: corpus/citations_class\06_1199.xml
# Processing: corpus/citations_class\06_12.xml
# Processing: corpus/citations_class\06_1200.xml
# Processing: corpus/citations_class\06_1201.xml
# Processing: corpus/citations_class\06_1202.xml
# Processing: corpus/citations_class\06_121.xml
# Processing: corpus/citations_class\06_1215.xml
# Processing: corpus/citations_class\06_1216.xml
# Processing: corpus/citations_class\06_1219.xml
# Processing: corpus/citations_class\06_122.xml
# Processing: corpus/citations_class\06_1220.xml
# Processing: corpus/citations_class\06_1222.xml
# Processing: corpus/citations_class\06_1223.xml
# Processing: corpus/citations_class\06_1227.xml
# Processing: corpus/citations_class\06_1228.xml
# Processing: corpus/citations_class\06_1229.xml
# Processing: corpus/citations_class\06_1230.xml
# Processing: corpus/citations_class\06_1234.xml
# Processing: corpus/citations_class\06_1235.xml
# Processing: corpus/citations_class\06_1236.xml
# Processing: corpus/citations_class\06_1237.xml
# Processing: corpus/citations_class\06_1239.xml
# Processing: corpus/citations_class\06_124.xml
# Processing: corpus/citations_class\06_1242.xml
# Processing: corpus/citations_class\06_1243.xml
# Processing: corpus/citations_class\06_1244.xml
# Processing: corpus/citations_class\06_1246.xml
# Processing: corpus/citations_class\06_1249.xml
# Processing: corpus/citations_class\06_125.xml
# Processing: corpus/citations_class\06_1250.xml
# Processing: corpus/citations_class\06_1252.xml
# Processing: corpus/citations_class\06_1254.xml
# Processing: corpus/citations_class\06_1255.xml
# Processing: corpus/citations_class\06_1259.xml
# Processing: corpus/citations_class\06_126.xml
# Processing: corpus/citations_class\06_1260.xml
# Processing: corpus/citations_class\06_1261.xml
# Processing: corpus/citations_class\06_1265.xml
# Processing: corpus/citations_class\06_1267.xml
# Processing: corpus/citations_class\06_1268.xml
# Processing: corpus/citations_class\06_1269.xml
# Processing: corpus/citations_class\06_1271.xml
# Processing: corpus/citations_class\06_1274.xml
# Processing: corpus/citations_class\06_1275.xml
# Processing: corpus/citations_class\06_128.xml
# Processing: corpus/citations_class\06_1285.xml
# Processing: corpus/citations_class\06_1288.xml
# Processing: corpus/citations_class\06_1289.xml
# Processing: corpus/citations_class\06_129.xml
# Processing: corpus/citations_class\06_1290.xml
# Processing: corpus/citations_class\06_1291.xml
# Processing: corpus/citations_class\06_1293.xml
# Processing: corpus/citations_class\06_1294.xml
# Processing: corpus/citations_class\06_1295.xml
# Processing: corpus/citations_class\06_1296.xml
# Processing: corpus/citations_class\06_1297.xml
# Processing: corpus/citations_class\06_1301.xml
# Processing: corpus/citations_class\06_1303.xml
# Processing: corpus/citations_class\06_1308.xml
# Processing: corpus/citations_class\06_1309.xml
# Processing: corpus/citations_class\06_131.xml
# Processing: corpus/citations_class\06_1318.xml
# Processing: corpus/citations_class\06_1321.xml
# Processing: corpus/citations_class\06_1324.xml
# Processing: corpus/citations_class\06_1325.xml
# Processing: corpus/citations_class\06_1326.xml
# Processing: corpus/citations_class\06_1327.xml
# Processing: corpus/citations_class\06_1328.xml
# Processing: corpus/citations_class\06_1329.xml
# Processing: corpus/citations_class\06_1330.xml
# Processing: corpus/citations_class\06_1334.xml
# Processing: corpus/citations_class\06_1335.xml
# Processing: corpus/citations_class\06_1336.xml
# Processing: corpus/citations_class\06_1338.xml
# Processing: corpus/citations_class\06_1343.xml
# Processing: corpus/citations_class\06_1346.xml
# Processing: corpus/citations_class\06_1347.xml
# Processing: corpus/citations_class\06_135.xml
# Processing: corpus/citations_class\06_1352.xml
# Processing: corpus/citations_class\06_1355.xml
# Processing: corpus/citations_class\06_1357.xml
# Processing: corpus/citations_class\06_136.xml
# Processing: corpus/citations_class\06_1361.xml
# Processing: corpus/citations_class\06_1363.xml
# Processing: corpus/citations_class\06_1367.xml
# Processing: corpus/citations_class\06_1368.xml
# Processing: corpus/citations_class\06_1369.xml
# Processing: corpus/citations_class\06_1373.xml
# Processing: corpus/citations_class\06_1374.xml
# Processing: corpus/citations_class\06_1376.xml
# Processing: corpus/citations_class\06_1379.xml
# Processing: corpus/citations_class\06_1381.xml
# Processing: corpus/citations_class\06_1387.xml
# Processing: corpus/citations_class\06_139.xml
# Processing: corpus/citations_class\06_1391.xml
# Processing: corpus/citations_class\06_1392.xml
# Processing: corpus/citations_class\06_1394.xml
# Processing: corpus/citations_class\06_1396.xml
# Processing: corpus/citations_class\06_1397.xml
# Processing: corpus/citations_class\06_1398.xml
# Processing: corpus/citations_class\06_14.xml
# Processing: corpus/citations_class\06_1401.xml
# Processing: corpus/citations_class\06_1402.xml
# Processing: corpus/citations_class\06_1403.xml
# Processing: corpus/citations_class\06_1404.xml
# Processing: corpus/citations_class\06_1406.xml
# Processing: corpus/citations_class\06_1407.xml
# Processing: corpus/citations_class\06_1408.xml
# Processing: corpus/citations_class\06_1409.xml
# Processing: corpus/citations_class\06_1412.xml
# Processing: corpus/citations_class\06_1413.xml
# Processing: corpus/citations_class\06_1414.xml
# Processing: corpus/citations_class\06_1416.xml
# Processing: corpus/citations_class\06_1420.xml
# Processing: corpus/citations_class\06_1426.xml
# Processing: corpus/citations_class\06_143.xml
# Processing: corpus/citations_class\06_1431.xml
# Processing: corpus/citations_class\06_1433.xml
# Processing: corpus/citations_class\06_1436.xml
# Processing: corpus/citations_class\06_1437.xml
# Processing: corpus/citations_class\06_1438.xml
# Processing: corpus/citations_class\06_1439.xml
# Processing: corpus/citations_class\06_1442.xml
# Processing: corpus/citations_class\06_1443.xml
# Processing: corpus/citations_class\06_1446.xml
# Processing: corpus/citations_class\06_1448.xml
# Processing: corpus/citations_class\06_1449.xml
# Processing: corpus/citations_class\06_1450.xml
# Processing: corpus/citations_class\06_1452.xml
# Processing: corpus/citations_class\06_1453.xml
# Processing: corpus/citations_class\06_1458.xml
# Processing: corpus/citations_class\06_146.xml
# Processing: corpus/citations_class\06_1470.xml
# Processing: corpus/citations_class\06_1472.xml
# Processing: corpus/citations_class\06_1474.xml
# Processing: corpus/citations_class\06_1475.xml
# Processing: corpus/citations_class\06_1477.xml
# Processing: corpus/citations_class\06_1478.xml
# Processing: corpus/citations_class\06_148.xml
# Processing: corpus/citations_class\06_1480.xml
# Processing: corpus/citations_class\06_1489.xml
# Processing: corpus/citations_class\06_1492.xml
# Processing: corpus/citations_class\06_1493.xml
# Processing: corpus/citations_class\06_1494.xml
# Processing: corpus/citations_class\06_1495.xml
# Processing: corpus/citations_class\06_1498.xml
# Processing: corpus/citations_class\06_15.xml
# Processing: corpus/citations_class\06_150.xml
# Processing: corpus/citations_class\06_1506.xml
# Processing: corpus/citations_class\06_1507.xml
# Processing: corpus/citations_class\06_1508.xml
# Processing: corpus/citations_class\06_151.xml
# Processing: corpus/citations_class\06_1517.xml
# Processing: corpus/citations_class\06_152.xml
# Processing: corpus/citations_class\06_1520.xml
# Processing: corpus/citations_class\06_1523.xml
# Processing: corpus/citations_class\06_1524.xml
# Processing: corpus/citations_class\06_1525.xml
# Processing: corpus/citations_class\06_1529.xml
# Processing: corpus/citations_class\06_1530.xml
# Processing: corpus/citations_class\06_1535.xml
# Processing: corpus/citations_class\06_1537.xml
# Processing: corpus/citations_class\06_1538.xml
# Processing: corpus/citations_class\06_1542.xml
# Processing: corpus/citations_class\06_1547.xml
# Processing: corpus/citations_class\06_1548.xml
# Processing: corpus/citations_class\06_1551.xml
# Processing: corpus/citations_class\06_1552.xml
# Processing: corpus/citations_class\06_1556.xml
# Processing: corpus/citations_class\06_1560.xml
# Processing: corpus/citations_class\06_1562.xml
# Processing: corpus/citations_class\06_157.xml
# Processing: corpus/citations_class\06_1574.xml
# Processing: corpus/citations_class\06_1575.xml
# Processing: corpus/citations_class\06_159.xml
# Processing: corpus/citations_class\06_1591.xml
# Processing: corpus/citations_class\06_1592.xml
# Processing: corpus/citations_class\06_1594.xml
# Processing: corpus/citations_class\06_1596.xml
# Processing: corpus/citations_class\06_1597.xml
# Processing: corpus/citations_class\06_16.xml
# Processing: corpus/citations_class\06_160.xml
# Processing: corpus/citations_class\06_1601.xml
# Processing: corpus/citations_class\06_1610.xml
# Processing: corpus/citations_class\06_1611.xml
# Processing: corpus/citations_class\06_1614.xml
# Processing: corpus/citations_class\06_1615.xml
# Processing: corpus/citations_class\06_1616.xml
# Processing: corpus/citations_class\06_1617.xml
# Processing: corpus/citations_class\06_1620.xml
# Processing: corpus/citations_class\06_1624.xml
# Processing: corpus/citations_class\06_1625.xml
# Processing: corpus/citations_class\06_1627.xml
# Processing: corpus/citations_class\06_163.xml
# Processing: corpus/citations_class\06_1630.xml
# Processing: corpus/citations_class\06_1632.xml
# Processing: corpus/citations_class\06_1637.xml
# Processing: corpus/citations_class\06_1639.xml
# Processing: corpus/citations_class\06_1640.xml
# Processing: corpus/citations_class\06_1641.xml
# Processing: corpus/citations_class\06_1642.xml
# Processing: corpus/citations_class\06_1644.xml
# Processing: corpus/citations_class\06_1645.xml
# Processing: corpus/citations_class\06_1646.xml
# Processing: corpus/citations_class\06_1652.xml
# Processing: corpus/citations_class\06_1653.xml
# Processing: corpus/citations_class\06_1654.xml
# Processing: corpus/citations_class\06_1655.xml
# Processing: corpus/citations_class\06_1657.xml
# Processing: corpus/citations_class\06_1661.xml
# Processing: corpus/citations_class\06_1663.xml
# Processing: corpus/citations_class\06_1667.xml
# Processing: corpus/citations_class\06_167.xml
# Processing: corpus/citations_class\06_1672.xml
# Processing: corpus/citations_class\06_1681.xml
# Processing: corpus/citations_class\06_1682.xml
# Processing: corpus/citations_class\06_1685.xml
# Processing: corpus/citations_class\06_1688.xml
# Processing: corpus/citations_class\06_1689.xml
# Processing: corpus/citations_class\06_1691.xml
# Processing: corpus/citations_class\06_1692.xml
# Processing: corpus/citations_class\06_1694.xml
# Processing: corpus/citations_class\06_1695.xml
# Processing: corpus/citations_class\06_1698.xml
# Processing: corpus/citations_class\06_17.xml
# Processing: corpus/citations_class\06_1700.xml
# Processing: corpus/citations_class\06_1702.xml
# Processing: corpus/citations_class\06_1706.xml
# Processing: corpus/citations_class\06_1707.xml
# Processing: corpus/citations_class\06_1708.xml
# Processing: corpus/citations_class\06_1710.xml
# Processing: corpus/citations_class\06_1711.xml
# Processing: corpus/citations_class\06_1712.xml
# Processing: corpus/citations_class\06_172.xml
# Processing: corpus/citations_class\06_1721.xml
# Processing: corpus/citations_class\06_1722.xml
# Processing: corpus/citations_class\06_1728.xml
# Processing: corpus/citations_class\06_1729.xml
# Processing: corpus/citations_class\06_173.xml
# Processing: corpus/citations_class\06_1733.xml
# Processing: corpus/citations_class\06_1735.xml
# Processing: corpus/citations_class\06_174.xml
# Processing: corpus/citations_class\06_1744.xml
# Processing: corpus/citations_class\06_1747.xml
# Processing: corpus/citations_class\06_1749.xml
# Processing: corpus/citations_class\06_1751.xml
# Processing: corpus/citations_class\06_1752.xml
# Processing: corpus/citations_class\06_1755.xml
# Processing: corpus/citations_class\06_1758.xml
# Processing: corpus/citations_class\06_1759.xml
# Processing: corpus/citations_class\06_176.xml
# Processing: corpus/citations_class\06_1762.xml
# Processing: corpus/citations_class\06_1763.xml
# Processing: corpus/citations_class\06_1764.xml
# Processing: corpus/citations_class\06_1768.xml
# Processing: corpus/citations_class\06_1770.xml
# Processing: corpus/citations_class\06_1771.xml
# Processing: corpus/citations_class\06_1772.xml
# Processing: corpus/citations_class\06_1774.xml
# Processing: corpus/citations_class\06_1777.xml
# Processing: corpus/citations_class\06_1779.xml
# Processing: corpus/citations_class\06_1780.xml
# Processing: corpus/citations_class\06_1781.xml
# Processing: corpus/citations_class\06_1782.xml
# Processing: corpus/citations_class\06_1784.xml
# Processing: corpus/citations_class\06_1786.xml
# Processing: corpus/citations_class\06_1787.xml
# Processing: corpus/citations_class\06_1790.xml
# Processing: corpus/citations_class\06_1792.xml
# Processing: corpus/citations_class\06_1798.xml
# Processing: corpus/citations_class\06_18.xml
# Processing: corpus/citations_class\06_180.xml
# Processing: corpus/citations_class\06_1803.xml
# Processing: corpus/citations_class\06_1804.xml
# Processing: corpus/citations_class\06_1806.xml
# Processing: corpus/citations_class\06_1811.xml
# Processing: corpus/citations_class\06_1817.xml
# Processing: corpus/citations_class\06_1819.xml
# Processing: corpus/citations_class\06_1825.xml
# Processing: corpus/citations_class\06_1826.xml
# Processing: corpus/citations_class\06_1829.xml
# Processing: corpus/citations_class\06_1839.xml
# Processing: corpus/citations_class\06_1846.xml
# Processing: corpus/citations_class\06_1849.xml
# Processing: corpus/citations_class\06_191.xml
# Processing: corpus/citations_class\06_192.xml
# Processing: corpus/citations_class\06_195.xml
# Processing: corpus/citations_class\06_199.xml
# Processing: corpus/citations_class\06_1999.xml
# Processing: corpus/citations_class\06_2007.xml
# Processing: corpus/citations_class\06_2008.xml
# Processing: corpus/citations_class\06_2009.xml
# Processing: corpus/citations_class\06_203.xml
# Processing: corpus/citations_class\06_208.xml
# Processing: corpus/citations_class\06_21.xml
# Processing: corpus/citations_class\06_212.xml
# Processing: corpus/citations_class\06_213.xml
# Processing: corpus/citations_class\06_219.xml
# Processing: corpus/citations_class\06_22.xml
# Processing: corpus/citations_class\06_224.xml
# Processing: corpus/citations_class\06_228.xml
# Processing: corpus/citations_class\06_23.xml
# Processing: corpus/citations_class\06_230.xml
# Processing: corpus/citations_class\06_231.xml
# Processing: corpus/citations_class\06_239.xml
# Processing: corpus/citations_class\06_247.xml
# Processing: corpus/citations_class\06_248.xml
# Processing: corpus/citations_class\06_25.xml
# Processing: corpus/citations_class\06_251.xml
# Processing: corpus/citations_class\06_254.xml
# Processing: corpus/citations_class\06_256.xml
# Processing: corpus/citations_class\06_26.xml
# Processing: corpus/citations_class\06_261.xml
# Processing: corpus/citations_class\06_262.xml
# Processing: corpus/citations_class\06_267.xml
# Processing: corpus/citations_class\06_270.xml
# Processing: corpus/citations_class\06_274.xml
# Processing: corpus/citations_class\06_277.xml
# Processing: corpus/citations_class\06_279.xml
# Processing: corpus/citations_class\06_28.xml
# Processing: corpus/citations_class\06_280.xml
# Processing: corpus/citations_class\06_3.xml
# Processing: corpus/citations_class\06_302.xml
# Processing: corpus/citations_class\06_303.xml
# Processing: corpus/citations_class\06_305.xml
# Processing: corpus/citations_class\06_306.xml
# Processing: corpus/citations_class\06_307.xml
# Processing: corpus/citations_class\06_314.xml
# Processing: corpus/citations_class\06_318.xml
# Processing: corpus/citations_class\06_32.xml
# Processing: corpus/citations_class\06_324.xml
# Processing: corpus/citations_class\06_325.xml
# Processing: corpus/citations_class\06_326.xml
# Processing: corpus/citations_class\06_327.xml
# Processing: corpus/citations_class\06_328.xml
# Processing: corpus/citations_class\06_330.xml
# Processing: corpus/citations_class\06_334.xml
# Processing: corpus/citations_class\06_336.xml
# Processing: corpus/citations_class\06_34.xml
# Processing: corpus/citations_class\06_341.xml
# Processing: corpus/citations_class\06_342.xml
# Processing: corpus/citations_class\06_348.xml
# Processing: corpus/citations_class\06_354.xml
# Processing: corpus/citations_class\06_355.xml
# Processing: corpus/citations_class\06_356.xml
# Processing: corpus/citations_class\06_36.xml
# Processing: corpus/citations_class\06_361.xml
# Processing: corpus/citations_class\06_362.xml
# Processing: corpus/citations_class\06_363.xml
# Processing: corpus/citations_class\06_364.xml
# Processing: corpus/citations_class\06_37.xml
# Processing: corpus/citations_class\06_371.xml
# Processing: corpus/citations_class\06_373.xml
# Processing: corpus/citations_class\06_379.xml
# Processing: corpus/citations_class\06_38.xml
# Processing: corpus/citations_class\06_383.xml
# Processing: corpus/citations_class\06_384.xml
# Processing: corpus/citations_class\06_385.xml
# Processing: corpus/citations_class\06_386.xml
# Processing: corpus/citations_class\06_387.xml
# Processing: corpus/citations_class\06_39.xml
# Processing: corpus/citations_class\06_395.xml
# Processing: corpus/citations_class\06_396.xml
# Processing: corpus/citations_class\06_397.xml
# Processing: corpus/citations_class\06_399.xml
# Processing: corpus/citations_class\06_40.xml
# Processing: corpus/citations_class\06_401.xml
# Processing: corpus/citations_class\06_402.xml
# Processing: corpus/citations_class\06_404.xml
# Processing: corpus/citations_class\06_407.xml
# Processing: corpus/citations_class\06_408.xml
# Processing: corpus/citations_class\06_416.xml
# Processing: corpus/citations_class\06_417.xml
# Processing: corpus/citations_class\06_420.xml
# Processing: corpus/citations_class\06_421.xml
# Processing: corpus/citations_class\06_426.xml
# Processing: corpus/citations_class\06_427.xml
# Processing: corpus/citations_class\06_428.xml
# Processing: corpus/citations_class\06_431.xml
# Processing: corpus/citations_class\06_432.xml
# Processing: corpus/citations_class\06_433.xml
# Processing: corpus/citations_class\06_434.xml
# Processing: corpus/citations_class\06_435.xml
# Processing: corpus/citations_class\06_437.xml
# Processing: corpus/citations_class\06_438.xml
# Processing: corpus/citations_class\06_44.xml
# Processing: corpus/citations_class\06_440.xml
# Processing: corpus/citations_class\06_442.xml
# Processing: corpus/citations_class\06_444.xml
# Processing: corpus/citations_class\06_445.xml
# Processing: corpus/citations_class\06_446.xml
# Processing: corpus/citations_class\06_449.xml
# Processing: corpus/citations_class\06_45.xml
# Processing: corpus/citations_class\06_450.xml
# Processing: corpus/citations_class\06_457.xml
# Processing: corpus/citations_class\06_458.xml
# Processing: corpus/citations_class\06_459.xml
# Processing: corpus/citations_class\06_460.xml
# Processing: corpus/citations_class\06_462.xml
# Processing: corpus/citations_class\06_463.xml
# Processing: corpus/citations_class\06_466.xml
# Processing: corpus/citations_class\06_468.xml
# Processing: corpus/citations_class\06_469.xml
# Processing: corpus/citations_class\06_472.xml
# Processing: corpus/citations_class\06_489.xml
# Processing: corpus/citations_class\06_494.xml
# Processing: corpus/citations_class\06_495.xml
# Processing: corpus/citations_class\06_497.xml
# Processing: corpus/citations_class\06_498.xml
# Processing: corpus/citations_class\06_499.xml
# Processing: corpus/citations_class\06_50.xml
# Processing: corpus/citations_class\06_500.xml
# Processing: corpus/citations_class\06_506.xml
# Processing: corpus/citations_class\06_507.xml
# Processing: corpus/citations_class\06_508.xml
# Processing: corpus/citations_class\06_509.xml
# Processing: corpus/citations_class\06_51.xml
# Processing: corpus/citations_class\06_511.xml
# Processing: corpus/citations_class\06_515.xml
# Processing: corpus/citations_class\06_516.xml
# Processing: corpus/citations_class\06_518.xml
# Processing: corpus/citations_class\06_519.xml
# Processing: corpus/citations_class\06_52.xml
# Processing: corpus/citations_class\06_520.xml
# Processing: corpus/citations_class\06_522.xml
# Processing: corpus/citations_class\06_524.xml
# Processing: corpus/citations_class\06_526.xml
# Processing: corpus/citations_class\06_527.xml
# Processing: corpus/citations_class\06_536.xml
# Processing: corpus/citations_class\06_538.xml
# Processing: corpus/citations_class\06_539.xml
# Processing: corpus/citations_class\06_540.xml
# Processing: corpus/citations_class\06_55.xml
# Processing: corpus/citations_class\06_555.xml
# Processing: corpus/citations_class\06_556.xml
# Processing: corpus/citations_class\06_559.xml
# Processing: corpus/citations_class\06_56.xml
# Processing: corpus/citations_class\06_57.xml
# Processing: corpus/citations_class\06_571.xml
# Processing: corpus/citations_class\06_573.xml
# Processing: corpus/citations_class\06_574.xml
# Processing: corpus/citations_class\06_575.xml
# Processing: corpus/citations_class\06_58.xml
# Processing: corpus/citations_class\06_582.xml
# Processing: corpus/citations_class\06_584.xml
# Processing: corpus/citations_class\06_587.xml
# Processing: corpus/citations_class\06_588.xml
# Processing: corpus/citations_class\06_589.xml
# Processing: corpus/citations_class\06_590.xml
# Processing: corpus/citations_class\06_591.xml
# Processing: corpus/citations_class\06_592.xml
# Processing: corpus/citations_class\06_598.xml
# Processing: corpus/citations_class\06_60.xml
# Processing: corpus/citations_class\06_600.xml
# Processing: corpus/citations_class\06_601.xml
# Processing: corpus/citations_class\06_603.xml
# Processing: corpus/citations_class\06_606.xml
# Processing: corpus/citations_class\06_607.xml
# Processing: corpus/citations_class\06_609.xml
# Processing: corpus/citations_class\06_610.xml
# Processing: corpus/citations_class\06_611.xml
# Processing: corpus/citations_class\06_613.xml
# Processing: corpus/citations_class\06_616.xml
# Processing: corpus/citations_class\06_617.xml
# Processing: corpus/citations_class\06_618.xml
# Processing: corpus/citations_class\06_622.xml
# Processing: corpus/citations_class\06_623.xml
# Processing: corpus/citations_class\06_624.xml
# Processing: corpus/citations_class\06_625.xml
# Processing: corpus/citations_class\06_626.xml
# Processing: corpus/citations_class\06_627.xml
# Processing: corpus/citations_class\06_63.xml
# Processing: corpus/citations_class\06_630.xml
# Processing: corpus/citations_class\06_631.xml
# Processing: corpus/citations_class\06_632.xml
# Processing: corpus/citations_class\06_633.xml
# Processing: corpus/citations_class\06_635.xml
# Processing: corpus/citations_class\06_636.xml
# Processing: corpus/citations_class\06_639.xml
# Processing: corpus/citations_class\06_640.xml
# Processing: corpus/citations_class\06_641.xml
# Processing: corpus/citations_class\06_642.xml
# Processing: corpus/citations_class\06_643.xml
# Processing: corpus/citations_class\06_644.xml
# Processing: corpus/citations_class\06_647.xml
# Processing: corpus/citations_class\06_648.xml
# Processing: corpus/citations_class\06_649.xml
# Processing: corpus/citations_class\06_650.xml
# Processing: corpus/citations_class\06_651.xml
# Processing: corpus/citations_class\06_652.xml
# Processing: corpus/citations_class\06_653.xml
# Processing: corpus/citations_class\06_655.xml
# Processing: corpus/citations_class\06_659.xml
# Processing: corpus/citations_class\06_660.xml
# Processing: corpus/citations_class\06_661.xml
# Processing: corpus/citations_class\06_662.xml
# Processing: corpus/citations_class\06_663.xml
# Processing: corpus/citations_class\06_668.xml
# Processing: corpus/citations_class\06_670.xml
# Processing: corpus/citations_class\06_671.xml
# Processing: corpus/citations_class\06_675.xml
# Processing: corpus/citations_class\06_679.xml
# Processing: corpus/citations_class\06_68.xml
# Processing: corpus/citations_class\06_682.xml
# Processing: corpus/citations_class\06_684.xml
# Processing: corpus/citations_class\06_685.xml
# Processing: corpus/citations_class\06_693.xml
# Processing: corpus/citations_class\06_695.xml
# Processing: corpus/citations_class\06_696.xml
# Processing: corpus/citations_class\06_699.xml
# Processing: corpus/citations_class\06_7.xml
# Processing: corpus/citations_class\06_700.xml
# Processing: corpus/citations_class\06_705.xml
# Processing: corpus/citations_class\06_706.xml
# Processing: corpus/citations_class\06_708.xml
# Processing: corpus/citations_class\06_709.xml
# Processing: corpus/citations_class\06_711.xml
# Processing: corpus/citations_class\06_714.xml
# Processing: corpus/citations_class\06_715.xml
# Processing: corpus/citations_class\06_717.xml
# Processing: corpus/citations_class\06_719.xml
# Processing: corpus/citations_class\06_722.xml
# Processing: corpus/citations_class\06_724.xml
# Processing: corpus/citations_class\06_725.xml
# Processing: corpus/citations_class\06_726.xml
# Processing: corpus/citations_class\06_727.xml
# Processing: corpus/citations_class\06_728.xml
# Processing: corpus/citations_class\06_733.xml
# Processing: corpus/citations_class\06_734.xml
# Processing: corpus/citations_class\06_735.xml
# Processing: corpus/citations_class\06_736.xml
# Processing: corpus/citations_class\06_739.xml
# Processing: corpus/citations_class\06_74.xml
# Processing: corpus/citations_class\06_740.xml
# Processing: corpus/citations_class\06_743.xml
# Processing: corpus/citations_class\06_745.xml
# Processing: corpus/citations_class\06_748.xml
# Processing: corpus/citations_class\06_752.xml
# Processing: corpus/citations_class\06_754.xml
# Processing: corpus/citations_class\06_755.xml
# Processing: corpus/citations_class\06_757.xml
# Processing: corpus/citations_class\06_758.xml
# Processing: corpus/citations_class\06_759.xml
# Processing: corpus/citations_class\06_76.xml
# Processing: corpus/citations_class\06_760.xml
# Processing: corpus/citations_class\06_761.xml
# Processing: corpus/citations_class\06_766.xml
# Processing: corpus/citations_class\06_767.xml
# Processing: corpus/citations_class\06_772.xml
# Processing: corpus/citations_class\06_773.xml
# Processing: corpus/citations_class\06_774.xml
# Processing: corpus/citations_class\06_779.xml
# Processing: corpus/citations_class\06_780.xml
# Processing: corpus/citations_class\06_781.xml
# Processing: corpus/citations_class\06_782.xml
# Processing: corpus/citations_class\06_783.xml
# Processing: corpus/citations_class\06_788.xml
# Processing: corpus/citations_class\06_79.xml
# Processing: corpus/citations_class\06_792.xml
# Processing: corpus/citations_class\06_793.xml
# Processing: corpus/citations_class\06_8.xml
# Processing: corpus/citations_class\06_802.xml
# Processing: corpus/citations_class\06_807.xml
# Processing: corpus/citations_class\06_808.xml
# Processing: corpus/citations_class\06_809.xml
# Processing: corpus/citations_class\06_810.xml
# Processing: corpus/citations_class\06_811.xml
# Processing: corpus/citations_class\06_812.xml
# Processing: corpus/citations_class\06_813.xml
# Processing: corpus/citations_class\06_814.xml
# Processing: corpus/citations_class\06_816.xml
# Processing: corpus/citations_class\06_818.xml
# Processing: corpus/citations_class\06_819.xml
# Processing: corpus/citations_class\06_82.xml
# Processing: corpus/citations_class\06_820.xml
# Processing: corpus/citations_class\06_821.xml
# Processing: corpus/citations_class\06_822.xml
# Processing: corpus/citations_class\06_825.xml
# Processing: corpus/citations_class\06_826.xml
# Processing: corpus/citations_class\06_828.xml
# Processing: corpus/citations_class\06_83.xml
# Processing: corpus/citations_class\06_831.xml
# Processing: corpus/citations_class\06_832.xml
# Processing: corpus/citations_class\06_833.xml
# Processing: corpus/citations_class\06_834.xml
# Processing: corpus/citations_class\06_836.xml
# Processing: corpus/citations_class\06_838.xml
# Processing: corpus/citations_class\06_840.xml
# Processing: corpus/citations_class\06_843.xml
# Processing: corpus/citations_class\06_845.xml
# Processing: corpus/citations_class\06_847.xml
# Processing: corpus/citations_class\06_848.xml
# Processing: corpus/citations_class\06_849.xml
# Processing: corpus/citations_class\06_850.xml
# Processing: corpus/citations_class\06_851.xml
# Processing: corpus/citations_class\06_852.xml
# Processing: corpus/citations_class\06_863.xml
# Processing: corpus/citations_class\06_869.xml
# Processing: corpus/citations_class\06_880.xml
# Processing: corpus/citations_class\06_881.xml
# Processing: corpus/citations_class\06_885.xml
# Processing: corpus/citations_class\06_886.xml
# Processing: corpus/citations_class\06_887.xml
# Processing: corpus/citations_class\06_888.xml
# Processing: corpus/citations_class\06_889.xml
# Processing: corpus/citations_class\06_890.xml
# Processing: corpus/citations_class\06_891.xml
# Processing: corpus/citations_class\06_893.xml
# Processing: corpus/citations_class\06_896.xml
# Processing: corpus/citations_class\06_897.xml
# Processing: corpus/citations_class\06_898.xml
# Processing: corpus/citations_class\06_899.xml
# Processing: corpus/citations_class\06_9.xml
# Processing: corpus/citations_class\06_90.xml
# Processing: corpus/citations_class\06_900.xml
# Processing: corpus/citations_class\06_901.xml
# Processing: corpus/citations_class\06_902.xml
# Processing: corpus/citations_class\06_903.xml
# Processing: corpus/citations_class\06_904.xml
# Processing: corpus/citations_class\06_905.xml
# Processing: corpus/citations_class\06_91.xml
# Processing: corpus/citations_class\06_912.xml
# Processing: corpus/citations_class\06_913.xml
# Processing: corpus/citations_class\06_914.xml
# Processing: corpus/citations_class\06_916.xml
# Processing: corpus/citations_class\06_917.xml
# Processing: corpus/citations_class\06_92.xml
# Processing: corpus/citations_class\06_920.xml
# Processing: corpus/citations_class\06_927.xml
# Processing: corpus/citations_class\06_93.xml
# Processing: corpus/citations_class\06_930.xml
# Processing: corpus/citations_class\06_931.xml
# Processing: corpus/citations_class\06_935.xml
# Processing: corpus/citations_class\06_936.xml
# Processing: corpus/citations_class\06_937.xml
# Processing: corpus/citations_class\06_939.xml
# Processing: corpus/citations_class\06_94.xml
# Processing: corpus/citations_class\06_941.xml
# Processing: corpus/citations_class\06_943.xml
# Processing: corpus/citations_class\06_944.xml
# Processing: corpus/citations_class\06_946.xml
# Processing: corpus/citations_class\06_949.xml
# Processing: corpus/citations_class\06_954.xml
# Processing: corpus/citations_class\06_955.xml
# Processing: corpus/citations_class\06_958.xml
# Processing: corpus/citations_class\06_96.xml
# Processing: corpus/citations_class\06_961.xml
# Processing: corpus/citations_class\06_964.xml
# Processing: corpus/citations_class\06_965.xml
# Processing: corpus/citations_class\06_979.xml
# Processing: corpus/citations_class\06_980.xml
# Processing: corpus/citations_class\06_981.xml
# Processing: corpus/citations_class\06_996.xml
# Processing: corpus/citations_class\06_997.xml
# Processing: corpus/citations_class\06_998.xml
# Processing: corpus/citations_class\06_999.xml
# Processing: corpus/citations_class\07_1.xml
# Processing: corpus/citations_class\07_10.xml
# Processing: corpus/citations_class\07_1000.xml
# Processing: corpus/citations_class\07_1003.xml
# Processing: corpus/citations_class\07_1004.xml
# Processing: corpus/citations_class\07_1009.xml
# Processing: corpus/citations_class\07_1010.xml
# Processing: corpus/citations_class\07_1011.xml
# Processing: corpus/citations_class\07_1012.xml
# Processing: corpus/citations_class\07_1025.xml
# Processing: corpus/citations_class\07_1028.xml
# Processing: corpus/citations_class\07_103.xml
# Processing: corpus/citations_class\07_1030.xml
# Processing: corpus/citations_class\07_1033.xml
# Processing: corpus/citations_class\07_1035.xml
# Processing: corpus/citations_class\07_1036.xml
# Processing: corpus/citations_class\07_1037.xml
# Processing: corpus/citations_class\07_1040.xml
# Processing: corpus/citations_class\07_1044.xml
# Processing: corpus/citations_class\07_1047.xml
# Processing: corpus/citations_class\07_1049.xml
# Processing: corpus/citations_class\07_1051.xml
# Processing: corpus/citations_class\07_1054.xml
# Processing: corpus/citations_class\07_1055.xml
# Processing: corpus/citations_class\07_1057.xml
# Processing: corpus/citations_class\07_1058.xml
# Processing: corpus/citations_class\07_1059.xml
# Processing: corpus/citations_class\07_1063.xml
# Processing: corpus/citations_class\07_1066.xml
# Processing: corpus/citations_class\07_1069.xml
# Processing: corpus/citations_class\07_1075.xml
# Processing: corpus/citations_class\07_1076.xml
# Processing: corpus/citations_class\07_1078.xml
# Processing: corpus/citations_class\07_1079.xml
# Processing: corpus/citations_class\07_1080.xml
# Processing: corpus/citations_class\07_1081.xml
# Processing: corpus/citations_class\07_1082.xml
# Processing: corpus/citations_class\07_1087.xml
# Processing: corpus/citations_class\07_1090.xml
# Processing: corpus/citations_class\07_1091.xml
# Processing: corpus/citations_class\07_1092.xml
# Processing: corpus/citations_class\07_1095.xml
# Processing: corpus/citations_class\07_1098.xml
# Processing: corpus/citations_class\07_11.xml
# Processing: corpus/citations_class\07_1100.xml
# Processing: corpus/citations_class\07_1104.xml
# Processing: corpus/citations_class\07_1107.xml
# Processing: corpus/citations_class\07_1108.xml
# Processing: corpus/citations_class\07_1117.xml
# Processing: corpus/citations_class\07_1123.xml
# Processing: corpus/citations_class\07_1124.xml
# Processing: corpus/citations_class\07_1125.xml
# Processing: corpus/citations_class\07_1129.xml
# Processing: corpus/citations_class\07_1132.xml
# Processing: corpus/citations_class\07_1136.xml
# Processing: corpus/citations_class\07_1138.xml
# Processing: corpus/citations_class\07_1139.xml
# Processing: corpus/citations_class\07_1140.xml
# Processing: corpus/citations_class\07_1141.xml
# Processing: corpus/citations_class\07_1142.xml
# Processing: corpus/citations_class\07_1152.xml
# Processing: corpus/citations_class\07_1154.xml
# Processing: corpus/citations_class\07_1159.xml
# Processing: corpus/citations_class\07_1161.xml
# Processing: corpus/citations_class\07_1162.xml
# Processing: corpus/citations_class\07_1164.xml
# Processing: corpus/citations_class\07_1165.xml
# Processing: corpus/citations_class\07_1167.xml
# Processing: corpus/citations_class\07_1171.xml
# Processing: corpus/citations_class\07_1172.xml
# Processing: corpus/citations_class\07_1174.xml
# Processing: corpus/citations_class\07_1175.xml
# Processing: corpus/citations_class\07_1176.xml
# Processing: corpus/citations_class\07_1178.xml
# Processing: corpus/citations_class\07_1179.xml
# Processing: corpus/citations_class\07_1182.xml
# Processing: corpus/citations_class\07_1183.xml
# Processing: corpus/citations_class\07_1185.xml
# Processing: corpus/citations_class\07_1188.xml
# Processing: corpus/citations_class\07_1189.xml
# Processing: corpus/citations_class\07_1191.xml
# Processing: corpus/citations_class\07_1193.xml
# Processing: corpus/citations_class\07_1194.xml
# Processing: corpus/citations_class\07_1195.xml
# Processing: corpus/citations_class\07_1197.xml
# Processing: corpus/citations_class\07_1204.xml
# Processing: corpus/citations_class\07_1205.xml
# Processing: corpus/citations_class\07_121.xml
# Processing: corpus/citations_class\07_1212.xml
# Processing: corpus/citations_class\07_1216.xml
# Processing: corpus/citations_class\07_1218.xml
# Processing: corpus/citations_class\07_122.xml
# Processing: corpus/citations_class\07_1224.xml
# Processing: corpus/citations_class\07_1226.xml
# Processing: corpus/citations_class\07_123.xml
# Processing: corpus/citations_class\07_1234.xml
# Processing: corpus/citations_class\07_1236.xml
# Processing: corpus/citations_class\07_1242.xml
# Processing: corpus/citations_class\07_1245.xml
# Processing: corpus/citations_class\07_1246.xml
# Processing: corpus/citations_class\07_1247.xml
# Processing: corpus/citations_class\07_1249.xml
# Processing: corpus/citations_class\07_1251.xml
# Processing: corpus/citations_class\07_1258.xml
# Processing: corpus/citations_class\07_1259.xml
# Processing: corpus/citations_class\07_1264.xml
# Processing: corpus/citations_class\07_1270.xml
# Processing: corpus/citations_class\07_1273.xml
# Processing: corpus/citations_class\07_1282.xml
# Processing: corpus/citations_class\07_1287.xml
# Processing: corpus/citations_class\07_1288.xml
# Processing: corpus/citations_class\07_129.xml
# Processing: corpus/citations_class\07_1290.xml
# Processing: corpus/citations_class\07_1295.xml
# Processing: corpus/citations_class\07_13.xml
# Processing: corpus/citations_class\07_1300.xml
# Processing: corpus/citations_class\07_1316.xml
# Processing: corpus/citations_class\07_1318.xml
# Processing: corpus/citations_class\07_1319.xml
# Processing: corpus/citations_class\07_1323.xml
# Processing: corpus/citations_class\07_1324.xml
# Processing: corpus/citations_class\07_1326.xml
# Processing: corpus/citations_class\07_1327.xml
# Processing: corpus/citations_class\07_1328.xml
# Processing: corpus/citations_class\07_1329.xml
# Processing: corpus/citations_class\07_133.xml
# Processing: corpus/citations_class\07_1332.xml
# Processing: corpus/citations_class\07_1333.xml
# Processing: corpus/citations_class\07_1338.xml
# Processing: corpus/citations_class\07_134.xml
# Processing: corpus/citations_class\07_1343.xml
# Processing: corpus/citations_class\07_1345.xml
# Processing: corpus/citations_class\07_1347.xml
# Processing: corpus/citations_class\07_1348.xml
# Processing: corpus/citations_class\07_1352.xml
# Processing: corpus/citations_class\07_1357.xml
# Processing: corpus/citations_class\07_1358.xml
# Processing: corpus/citations_class\07_1359.xml
# Processing: corpus/citations_class\07_1364.xml
# Processing: corpus/citations_class\07_1367.xml
# Processing: corpus/citations_class\07_137.xml
# Processing: corpus/citations_class\07_1371.xml
# Processing: corpus/citations_class\07_1373.xml
# Processing: corpus/citations_class\07_1375.xml
# Processing: corpus/citations_class\07_1377.xml
# Processing: corpus/citations_class\07_1379.xml
# Processing: corpus/citations_class\07_138.xml
# Processing: corpus/citations_class\07_1380.xml
# Processing: corpus/citations_class\07_1382.xml
# Processing: corpus/citations_class\07_1384.xml
# Processing: corpus/citations_class\07_1387.xml
# Processing: corpus/citations_class\07_1388.xml
# Processing: corpus/citations_class\07_1389.xml
# Processing: corpus/citations_class\07_139.xml
# Processing: corpus/citations_class\07_1395.xml
# Processing: corpus/citations_class\07_1397.xml
# Processing: corpus/citations_class\07_1398.xml
# Processing: corpus/citations_class\07_1399.xml
# Processing: corpus/citations_class\07_14.xml
# Processing: corpus/citations_class\07_1400.xml
# Processing: corpus/citations_class\07_1402.xml
# Processing: corpus/citations_class\07_1407.xml
# Processing: corpus/citations_class\07_1408.xml
# Processing: corpus/citations_class\07_1409.xml
# Processing: corpus/citations_class\07_1410.xml
# Processing: corpus/citations_class\07_1411.xml
# Processing: corpus/citations_class\07_1415.xml
# Processing: corpus/citations_class\07_142.xml
# Processing: corpus/citations_class\07_1421.xml
# Processing: corpus/citations_class\07_1422.xml
# Processing: corpus/citations_class\07_1425.xml
# Processing: corpus/citations_class\07_1429.xml
# Processing: corpus/citations_class\07_143.xml
# Processing: corpus/citations_class\07_1433.xml
# Processing: corpus/citations_class\07_1434.xml
# Processing: corpus/citations_class\07_1439.xml
# Processing: corpus/citations_class\07_144.xml
# Processing: corpus/citations_class\07_1443.xml
# Processing: corpus/citations_class\07_1445.xml
# Processing: corpus/citations_class\07_1447.xml
# Processing: corpus/citations_class\07_1448.xml
# Processing: corpus/citations_class\07_1449.xml
# Processing: corpus/citations_class\07_1460.xml
# Processing: corpus/citations_class\07_1461.xml
# Processing: corpus/citations_class\07_1463.xml
# Processing: corpus/citations_class\07_1465.xml
# Processing: corpus/citations_class\07_1468.xml
# Processing: corpus/citations_class\07_1479.xml
# Processing: corpus/citations_class\07_1480.xml
# Processing: corpus/citations_class\07_1482.xml
# Processing: corpus/citations_class\07_1484.xml
# Processing: corpus/citations_class\07_1485.xml
# Processing: corpus/citations_class\07_1486.xml
# Processing: corpus/citations_class\07_1490.xml
# Processing: corpus/citations_class\07_1491.xml
# Processing: corpus/citations_class\07_1493.xml
# Processing: corpus/citations_class\07_1496.xml
# Processing: corpus/citations_class\07_15.xml
# Processing: corpus/citations_class\07_1500.xml
# Processing: corpus/citations_class\07_1503.xml
# Processing: corpus/citations_class\07_1504.xml
# Processing: corpus/citations_class\07_1505.xml
# Processing: corpus/citations_class\07_1507.xml
# Processing: corpus/citations_class\07_1508.xml
# Processing: corpus/citations_class\07_1509.xml
# Processing: corpus/citations_class\07_1512.xml
# Processing: corpus/citations_class\07_1513.xml
# Processing: corpus/citations_class\07_1515.xml
# Processing: corpus/citations_class\07_1518.xml
# Processing: corpus/citations_class\07_1519.xml
# Processing: corpus/citations_class\07_1520.xml
# Processing: corpus/citations_class\07_1522.xml
# Processing: corpus/citations_class\07_1526.xml
# Processing: corpus/citations_class\07_1528.xml
# Processing: corpus/citations_class\07_1530.xml
# Processing: corpus/citations_class\07_1531.xml
# Processing: corpus/citations_class\07_1532.xml
# Processing: corpus/citations_class\07_1533.xml
# Processing: corpus/citations_class\07_1535.xml
# Processing: corpus/citations_class\07_1536.xml
# Processing: corpus/citations_class\07_1538.xml
# Processing: corpus/citations_class\07_1539.xml
# Processing: corpus/citations_class\07_1541.xml
# Processing: corpus/citations_class\07_1542.xml
# Processing: corpus/citations_class\07_1545.xml
# Processing: corpus/citations_class\07_1546.xml
# Processing: corpus/citations_class\07_1547.xml
# Processing: corpus/citations_class\07_1548.xml
# Processing: corpus/citations_class\07_155.xml
# Processing: corpus/citations_class\07_1550.xml
# Processing: corpus/citations_class\07_1551.xml
# Processing: corpus/citations_class\07_1555.xml
# Processing: corpus/citations_class\07_1556.xml
# Processing: corpus/citations_class\07_1557.xml
# Processing: corpus/citations_class\07_1558.xml
# Processing: corpus/citations_class\07_1559.xml
# Processing: corpus/citations_class\07_1560.xml
# Processing: corpus/citations_class\07_1561.xml
# Processing: corpus/citations_class\07_1562.xml
# Processing: corpus/citations_class\07_1564.xml
# Processing: corpus/citations_class\07_1565.xml
# Processing: corpus/citations_class\07_1567.xml
# Processing: corpus/citations_class\07_1568.xml
# Processing: corpus/citations_class\07_157.xml
# Processing: corpus/citations_class\07_1570.xml
# Processing: corpus/citations_class\07_1571.xml
# Processing: corpus/citations_class\07_1582.xml
# Processing: corpus/citations_class\07_1583.xml
# Processing: corpus/citations_class\07_1586.xml
# Processing: corpus/citations_class\07_1589.xml
# Processing: corpus/citations_class\07_1591.xml
# Processing: corpus/citations_class\07_1592.xml
# Processing: corpus/citations_class\07_1594.xml
# Processing: corpus/citations_class\07_1597.xml
# Processing: corpus/citations_class\07_1598.xml
# Processing: corpus/citations_class\07_16.xml
# Processing: corpus/citations_class\07_1601.xml
# Processing: corpus/citations_class\07_1603.xml
# Processing: corpus/citations_class\07_1607.xml
# Processing: corpus/citations_class\07_1608.xml
# Processing: corpus/citations_class\07_1609.xml
# Processing: corpus/citations_class\07_161.xml
# Processing: corpus/citations_class\07_1612.xml
# Processing: corpus/citations_class\07_1615.xml
# Processing: corpus/citations_class\07_1617.xml
# Processing: corpus/citations_class\07_1619.xml
# Processing: corpus/citations_class\07_1621.xml
# Processing: corpus/citations_class\07_1625.xml
# Processing: corpus/citations_class\07_163.xml
# Processing: corpus/citations_class\07_1634.xml
# Processing: corpus/citations_class\07_1635.xml
# Processing: corpus/citations_class\07_1636.xml
# Processing: corpus/citations_class\07_1637.xml
# Processing: corpus/citations_class\07_1639.xml
# Processing: corpus/citations_class\07_1642.xml
# Processing: corpus/citations_class\07_1648.xml
# Processing: corpus/citations_class\07_1649.xml
# Processing: corpus/citations_class\07_165.xml
# Processing: corpus/citations_class\07_1650.xml
# Processing: corpus/citations_class\07_1652.xml
# Processing: corpus/citations_class\07_1653.xml
# Processing: corpus/citations_class\07_1655.xml
# Processing: corpus/citations_class\07_1659.xml
# Processing: corpus/citations_class\07_166.xml
# Processing: corpus/citations_class\07_1660.xml
# Processing: corpus/citations_class\07_1662.xml
# Processing: corpus/citations_class\07_1664.xml
# Processing: corpus/citations_class\07_1667.xml
# Processing: corpus/citations_class\07_1668.xml
# Processing: corpus/citations_class\07_167.xml
# Processing: corpus/citations_class\07_1673.xml
# Processing: corpus/citations_class\07_1674.xml
# Processing: corpus/citations_class\07_1680.xml
# Processing: corpus/citations_class\07_1684.xml
# Processing: corpus/citations_class\07_1687.xml
# Processing: corpus/citations_class\07_169.xml
# Processing: corpus/citations_class\07_1692.xml
# Processing: corpus/citations_class\07_1693.xml
# Processing: corpus/citations_class\07_1694.xml
# Processing: corpus/citations_class\07_1695.xml
# Processing: corpus/citations_class\07_1696.xml
# Processing: corpus/citations_class\07_1701.xml
# Processing: corpus/citations_class\07_1703.xml
# Processing: corpus/citations_class\07_1705.xml
# ...
# Processing: corpus/citations_class\09_159.xml
# Processing: corpus/citations_class\09_1590.xml
# Processing: corpus/citations_class\09_1598.xml
# Processing: corpus/citations_class\09_16.xml
# Processing: corpus/citations_class\09_166.xml
# Processing: corpus/citations_class\09_17.xml
# Processing: corpus/citations_class\09_171.xml
# Processing: corpus/citations_class\09_175.xml
# Processing: corpus/citations_class\09_177.xml
# Processing: corpus/citations_class\09_180.xml
# Processing: corpus/citations_class\09_181.xml
# Processing: corpus/citations_class\09_182.xml
# Processing: corpus/citations_class\09_188.xml
# Processing: corpus/citations_class\09_189.xml
# Processing: corpus/citations_class\09_190.xml
# Processing: corpus/citations_class\09_196.xml
# Processing: corpus/citations_class\09_197.xml
# Processing: corpus/citations_class\09_199.xml
# Processing: corpus/citations_class\09_202.xml
# Processing: corpus/citations_class\09_205.xml
# Processing: corpus/citations_class\09_206.xml
# Processing: corpus/citations_class\09_207.xml
# Processing: corpus/citations_class\09_208.xml
# Processing: corpus/citations_class\09_209.xml
# Processing: corpus/citations_class\09_216.xml
# Processing: corpus/citations_class\09_217.xml
# Processing: corpus/citations_class\09_218.xml
# Processing: corpus/citations_class\09_22.xml
# Processing: corpus/citations_class\09_220.xml
# Processing: corpus/citations_class\09_222.xml
# Processing: corpus/citations_class\09_228.xml
# Processing: corpus/citations_class\09_231.xml
# Processing: corpus/citations_class\09_233.xml
# Processing: corpus/citations_class\09_237.xml
# Processing: corpus/citations_class\09_238.xml
# Processing: corpus/citations_class\09_239.xml
# Processing: corpus/citations_class\09_240.xml
# Processing: corpus/citations_class\09_241.xml
# Processing: corpus/citations_class\09_243.xml
# Processing: corpus/citations_class\09_245.xml
# Processing: corpus/citations_class\09_246.xml
# Processing: corpus/citations_class\09_248.xml
# Processing: corpus/citations_class\09_249.xml
# Processing: corpus/citations_class\09_25.xml
# Processing: corpus/citations_class\09_250.xml
# Processing: corpus/citations_class\09_252.xml
# Processing: corpus/citations_class\09_253.xml
# Processing: corpus/citations_class\09_254.xml
# Processing: corpus/citations_class\09_257.xml
# Processing: corpus/citations_class\09_258.xml
# Processing: corpus/citations_class\09_260.xml
# Processing: corpus/citations_class\09_262.xml
# Processing: corpus/citations_class\09_264.xml
# Processing: corpus/citations_class\09_266.xml
# Processing: corpus/citations_class\09_268.xml
# Processing: corpus/citations_class\09_269.xml
# Processing: corpus/citations_class\09_270.xml
# Processing: corpus/citations_class\09_271.xml
# Processing: corpus/citations_class\09_272.xml
# Processing: corpus/citations_class\09_274.xml
# Processing: corpus/citations_class\09_278.xml
# Processing: corpus/citations_class\09_28.xml
# Processing: corpus/citations_class\09_282.xml
# Processing: corpus/citations_class\09_284.xml
# Processing: corpus/citations_class\09_29.xml
# Processing: corpus/citations_class\09_291.xml
# Processing: corpus/citations_class\09_294.xml
# Processing: corpus/citations_class\09_298.xml
# Processing: corpus/citations_class\09_299.xml
# Processing: corpus/citations_class\09_30.xml
# Processing: corpus/citations_class\09_302.xml
# Processing: corpus/citations_class\09_304.xml
# Processing: corpus/citations_class\09_305.xml
# Processing: corpus/citations_class\09_306.xml
# Processing: corpus/citations_class\09_307.xml
# Processing: corpus/citations_class\09_311.xml
# Processing: corpus/citations_class\09_312.xml
# Processing: corpus/citations_class\09_313.xml
# Processing: corpus/citations_class\09_314.xml
# Processing: corpus/citations_class\09_315.xml
# Processing: corpus/citations_class\09_316.xml
# Processing: corpus/citations_class\09_319.xml
# Processing: corpus/citations_class\09_320.xml
# Processing: corpus/citations_class\09_322.xml
# Processing: corpus/citations_class\09_324.xml
# Processing: corpus/citations_class\09_325.xml
# Processing: corpus/citations_class\09_326.xml
# Processing: corpus/citations_class\09_327.xml
# Processing: corpus/citations_class\09_332.xml
# Processing: corpus/citations_class\09_338.xml
# Processing: corpus/citations_class\09_349.xml
# Processing: corpus/citations_class\09_354.xml
# Processing: corpus/citations_class\09_356.xml
# Processing: corpus/citations_class\09_36.xml
# Processing: corpus/citations_class\09_364.xml
# Processing: corpus/citations_class\09_367.xml
# Processing: corpus/citations_class\09_37.xml
# Processing: corpus/citations_class\09_374.xml
# Processing: corpus/citations_class\09_38.xml
# Processing: corpus/citations_class\09_385.xml
# Processing: corpus/citations_class\09_388.xml
# Processing: corpus/citations_class\09_389.xml
# Processing: corpus/citations_class\09_39.xml
# Processing: corpus/citations_class\09_392.xml
# Processing: corpus/citations_class\09_395.xml
# Processing: corpus/citations_class\09_399.xml
# Processing: corpus/citations_class\09_40.xml
# Processing: corpus/citations_class\09_400.xml
# Processing: corpus/citations_class\09_401.xml
# Processing: corpus/citations_class\09_403.xml
# Processing: corpus/citations_class\09_404.xml
# Processing: corpus/citations_class\09_409.xml
# Processing: corpus/citations_class\09_41.xml
# Processing: corpus/citations_class\09_410.xml
# Processing: corpus/citations_class\09_413.xml
# Processing: corpus/citations_class\09_414.xml
# Processing: corpus/citations_class\09_417.xml
# Processing: corpus/citations_class\09_418.xml
# Processing: corpus/citations_class\09_422.xml
# Processing: corpus/citations_class\09_426.xml
# Processing: corpus/citations_class\09_427.xml
# Processing: corpus/citations_class\09_428.xml
# Processing: corpus/citations_class\09_429.xml
# Processing: corpus/citations_class\09_432.xml
# Processing: corpus/citations_class\09_433.xml
# Processing: corpus/citations_class\09_438.xml
# Processing: corpus/citations_class\09_441.xml
# Processing: corpus/citations_class\09_452.xml
# Processing: corpus/citations_class\09_462.xml
# Processing: corpus/citations_class\09_474.xml
# Processing: corpus/citations_class\09_475.xml
# Processing: corpus/citations_class\09_477.xml
# Processing: corpus/citations_class\09_480.xml
# Processing: corpus/citations_class\09_481.xml
# Processing: corpus/citations_class\09_486.xml
# Processing: corpus/citations_class\09_487.xml
# Processing: corpus/citations_class\09_49.xml
# Processing: corpus/citations_class\09_493.xml
# Processing: corpus/citations_class\09_494.xml
# Processing: corpus/citations_class\09_496.xml
# Processing: corpus/citations_class\09_498.xml
# Processing: corpus/citations_class\09_499.xml
# Processing: corpus/citations_class\09_50.xml
# Processing: corpus/citations_class\09_500.xml
# Processing: corpus/citations_class\09_504.xml
# Processing: corpus/citations_class\09_506.xml
# Processing: corpus/citations_class\09_509.xml
# Processing: corpus/citations_class\09_510.xml
# Processing: corpus/citations_class\09_515.xml
# Processing: corpus/citations_class\09_516.xml
# Processing: corpus/citations_class\09_517.xml
# Processing: corpus/citations_class\09_519.xml
# Processing: corpus/citations_class\09_52.xml
# Processing: corpus/citations_class\09_521.xml
# Processing: corpus/citations_class\09_522.xml
# Processing: corpus/citations_class\09_528.xml
# Processing: corpus/citations_class\09_53.xml
# Processing: corpus/citations_class\09_530.xml
# Processing: corpus/citations_class\09_532.xml
# Processing: corpus/citations_class\09_538.xml
# Processing: corpus/citations_class\09_539.xml
# Processing: corpus/citations_class\09_54.xml
# Processing: corpus/citations_class\09_540.xml
# Processing: corpus/citations_class\09_543.xml
# Processing: corpus/citations_class\09_546.xml
# Processing: corpus/citations_class\09_551.xml
# Processing: corpus/citations_class\09_554.xml
# Processing: corpus/citations_class\09_555.xml
# Processing: corpus/citations_class\09_556.xml
# Processing: corpus/citations_class\09_558.xml
# Processing: corpus/citations_class\09_56.xml
# Processing: corpus/citations_class\09_560.xml
# Processing: corpus/citations_class\09_561.xml
# Processing: corpus/citations_class\09_562.xml
# Processing: corpus/citations_class\09_567.xml
# Processing: corpus/citations_class\09_57.xml
# Processing: corpus/citations_class\09_571.xml
# Processing: corpus/citations_class\09_572.xml
# Processing: corpus/citations_class\09_578.xml
# Processing: corpus/citations_class\09_579.xml
# Processing: corpus/citations_class\09_58.xml
# Processing: corpus/citations_class\09_584.xml
# Processing: corpus/citations_class\09_585.xml
# Processing: corpus/citations_class\09_589.xml
# Processing: corpus/citations_class\09_59.xml
# Processing: corpus/citations_class\09_590.xml
# Processing: corpus/citations_class\09_593.xml
# Processing: corpus/citations_class\09_594.xml
# Processing: corpus/citations_class\09_595.xml
# Processing: corpus/citations_class\09_596.xml
# Processing: corpus/citations_class\09_597.xml
# Processing: corpus/citations_class\09_599.xml
# Processing: corpus/citations_class\09_6.xml
# Processing: corpus/citations_class\09_600.xml
# Processing: corpus/citations_class\09_601.xml
# Processing: corpus/citations_class\09_606.xml
# Processing: corpus/citations_class\09_608.xml
# Processing: corpus/citations_class\09_613.xml
# Processing: corpus/citations_class\09_619.xml
# Processing: corpus/citations_class\09_62.xml
# Processing: corpus/citations_class\09_620.xml
# Processing: corpus/citations_class\09_622.xml
# Processing: corpus/citations_class\09_625.xml
# Processing: corpus/citations_class\09_63.xml
# Processing: corpus/citations_class\09_632.xml
# Processing: corpus/citations_class\09_636.xml
# Processing: corpus/citations_class\09_637.xml
# Processing: corpus/citations_class\09_639.xml
# Processing: corpus/citations_class\09_642.xml
# Processing: corpus/citations_class\09_650.xml
# Processing: corpus/citations_class\09_654.xml
# Processing: corpus/citations_class\09_656.xml
# Processing: corpus/citations_class\09_666.xml
# Processing: corpus/citations_class\09_667.xml
# Processing: corpus/citations_class\09_668.xml
# Processing: corpus/citations_class\09_672.xml
# Processing: corpus/citations_class\09_675.xml
# Processing: corpus/citations_class\09_678.xml
# Processing: corpus/citations_class\09_679.xml
# Processing: corpus/citations_class\09_68.xml
# Processing: corpus/citations_class\09_680.xml
# Processing: corpus/citations_class\09_681.xml
# Processing: corpus/citations_class\09_685.xml
# Processing: corpus/citations_class\09_686.xml
# Processing: corpus/citations_class\09_688.xml
# Processing: corpus/citations_class\09_694.xml
# Processing: corpus/citations_class\09_699.xml
# Processing: corpus/citations_class\09_70.xml
# Processing: corpus/citations_class\09_700.xml
# Processing: corpus/citations_class\09_704.xml
# Processing: corpus/citations_class\09_71.xml
# Processing: corpus/citations_class\09_710.xml
# Processing: corpus/citations_class\09_712.xml
# Processing: corpus/citations_class\09_714.xml
# Processing: corpus/citations_class\09_715.xml
# Processing: corpus/citations_class\09_717.xml
# Processing: corpus/citations_class\09_724.xml
# Processing: corpus/citations_class\09_726.xml
# Processing: corpus/citations_class\09_727.xml
# Processing: corpus/citations_class\09_728.xml
# Processing: corpus/citations_class\09_731.xml
# Processing: corpus/citations_class\09_735.xml
# Processing: corpus/citations_class\09_742.xml
# Processing: corpus/citations_class\09_743.xml
# Processing: corpus/citations_class\09_744.xml
# Processing: corpus/citations_class\09_747.xml
# Processing: corpus/citations_class\09_749.xml
# Processing: corpus/citations_class\09_752.xml
# Processing: corpus/citations_class\09_753.xml
# Processing: corpus/citations_class\09_754.xml
# Processing: corpus/citations_class\09_755.xml
# Processing: corpus/citations_class\09_757.xml
# Processing: corpus/citations_class\09_758.xml
# Processing: corpus/citations_class\09_759.xml
# Processing: corpus/citations_class\09_763.xml
# Processing: corpus/citations_class\09_772.xml
# Processing: corpus/citations_class\09_774.xml
# Processing: corpus/citations_class\09_776.xml
# Processing: corpus/citations_class\09_778.xml
# Processing: corpus/citations_class\09_779.xml
# Processing: corpus/citations_class\09_781.xml
# Processing: corpus/citations_class\09_784.xml
# Processing: corpus/citations_class\09_785.xml
# Processing: corpus/citations_class\09_786.xml
# Processing: corpus/citations_class\09_787.xml
# Processing: corpus/citations_class\09_789.xml
# Processing: corpus/citations_class\09_79.xml
# Processing: corpus/citations_class\09_791.xml
# Processing: corpus/citations_class\09_794.xml
# Processing: corpus/citations_class\09_795.xml
# Processing: corpus/citations_class\09_799.xml
# Processing: corpus/citations_class\09_800.xml
# Processing: corpus/citations_class\09_801.xml
# Processing: corpus/citations_class\09_802.xml
# Processing: corpus/citations_class\09_819.xml
# Processing: corpus/citations_class\09_82.xml
# Processing: corpus/citations_class\09_829.xml
# Processing: corpus/citations_class\09_830.xml
# Processing: corpus/citations_class\09_834.xml
# Processing: corpus/citations_class\09_837.xml
# Processing: corpus/citations_class\09_838.xml
# Processing: corpus/citations_class\09_839.xml
# Processing: corpus/citations_class\09_844.xml
# Processing: corpus/citations_class\09_845.xml
# Processing: corpus/citations_class\09_846.xml
# Processing: corpus/citations_class\09_850.xml
# Processing: corpus/citations_class\09_851.xml
# Processing: corpus/citations_class\09_852.xml
# Processing: corpus/citations_class\09_865.xml
# Processing: corpus/citations_class\09_87.xml
# Processing: corpus/citations_class\09_872.xml
# Processing: corpus/citations_class\09_873.xml
# Processing: corpus/citations_class\09_875.xml
# Processing: corpus/citations_class\09_877.xml
# Processing: corpus/citations_class\09_878.xml
# Processing: corpus/citations_class\09_880.xml
# Processing: corpus/citations_class\09_881.xml
# Processing: corpus/citations_class\09_886.xml
# Processing: corpus/citations_class\09_887.xml
# Processing: corpus/citations_class\09_888.xml
# Processing: corpus/citations_class\09_890.xml
# Processing: corpus/citations_class\09_891.xml
# Processing: corpus/citations_class\09_892.xml
# Processing: corpus/citations_class\09_90.xml
# Processing: corpus/citations_class\09_903.xml
# Processing: corpus/citations_class\09_904.xml
# Processing: corpus/citations_class\09_905.xml
# Processing: corpus/citations_class\09_907.xml
# Processing: corpus/citations_class\09_908.xml
# Processing: corpus/citations_class\09_909.xml
# Processing: corpus/citations_class\09_911.xml
# Processing: corpus/citations_class\09_912.xml
# Processing: corpus/citations_class\09_915.xml
# Processing: corpus/citations_class\09_922.xml
# Processing: corpus/citations_class\09_93.xml
# Processing: corpus/citations_class\09_935.xml
# Processing: corpus/citations_class\09_936.xml
# Processing: corpus/citations_class\09_938.xml
# Processing: corpus/citations_class\09_946.xml
# Processing: corpus/citations_class\09_947.xml
# Processing: corpus/citations_class\09_949.xml
# Processing: corpus/citations_class\09_950.xml
# Processing: corpus/citations_class\09_951.xml
# Processing: corpus/citations_class\09_952.xml
# Processing: corpus/citations_class\09_953.xml
# Processing: corpus/citations_class\09_956.xml
# Processing: corpus/citations_class\09_958.xml
# Processing: corpus/citations_class\09_959.xml
# Processing: corpus/citations_class\09_96.xml
# Processing: corpus/citations_class\09_962.xml
# Processing: corpus/citations_class\09_963.xml
# Processing: corpus/citations_class\09_966.xml
# Processing: corpus/citations_class\09_967.xml
# Processing: corpus/citations_class\09_968.xml
# Processing: corpus/citations_class\09_97.xml
# Processing: corpus/citations_class\09_971.xml
# Processing: corpus/citations_class\09_972.xml
# Processing: corpus/citations_class\09_977.xml
# Processing: corpus/citations_class\09_979.xml
# Processing: corpus/citations_class\09_980.xml
# Processing: corpus/citations_class\09_981.xml
# Processing: corpus/citations_class\09_983.xml
# Processing: corpus/citations_class\09_984.xml
# Processing: corpus/citations_class\09_99.xml
# Processing: corpus/citations_class\09_990.xml
# Processing: corpus/citations_class\09_991.xml
# Processing: corpus/citations_class\09_992.xml
# Processing: corpus/citations_class\09_993.xml

# %% [markdown]
# <h2> Parse all XML Files in the citations_class Directory and extract labels/sentences</h2>

# %%
#Function Call to extract labels/sentecnces from the citations_class directory xml files
extract_from_dir('corpus/citations_class','output.txt')
# Out:
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1001.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1004.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1005.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1017.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1019.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_102.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1021.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1022.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1023.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1027.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1033.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1041.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1042.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1043.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1044.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1045.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1050.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1054.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_106.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1066.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1069.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_107.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1071.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1072.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1074.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1077.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1080.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1082.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1083.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1084.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1086.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1088.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1089.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1095.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1096.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_11.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1101.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1106.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1107.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_111.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1110.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1112.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1113.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1114.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1115.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1117.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1119.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1122.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1129.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1130.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1133.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1138.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1147.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1156.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_116.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1163.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1166.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1168.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1169.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1170.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1172.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1173.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1174.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1175.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1176.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1177.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1184.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1186.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1190.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1197.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1199.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_12.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1200.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1201.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1202.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_121.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1215.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1216.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1219.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_122.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1220.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1222.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1223.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1227.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1228.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1229.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1230.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1234.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1235.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1236.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1237.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1239.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_124.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1242.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1243.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1244.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1246.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1249.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_125.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1250.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1252.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1254.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1255.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1259.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_126.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1260.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1261.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1265.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1267.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1268.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1269.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1271.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1274.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1275.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_128.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1285.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1288.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1289.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_129.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1290.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1291.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1293.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1294.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1295.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1296.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1297.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1301.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1303.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1308.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1309.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_131.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1318.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1321.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1324.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1325.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1326.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1327.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1328.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1329.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1330.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1334.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1335.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1336.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1338.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1343.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1346.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1347.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_135.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1352.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1355.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1357.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_136.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1361.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1363.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1367.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1368.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1369.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1373.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1374.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1376.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1379.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1381.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1387.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_139.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1391.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1392.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1394.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1396.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1397.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1398.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_14.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1401.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1402.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1403.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1404.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1406.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1407.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1408.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1409.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1412.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1413.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1414.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1416.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1420.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1426.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_143.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1431.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1433.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1436.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1437.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1438.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1439.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1442.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1443.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1446.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1448.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1449.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1450.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1452.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1453.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1458.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_146.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1470.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1472.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1474.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1475.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1477.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1478.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_148.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1480.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1489.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1492.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1493.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1494.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1495.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1498.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_15.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_150.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1506.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1507.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1508.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_151.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1517.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_152.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1520.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1523.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1524.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1525.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1529.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1530.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1535.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1537.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1538.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1542.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1547.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1548.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1551.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1552.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1556.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1560.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1562.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_157.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1574.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1575.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_159.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1591.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1592.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1594.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1596.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1597.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_16.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_160.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1601.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1610.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1611.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1614.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1615.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1616.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1617.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1620.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1624.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1625.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1627.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_163.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1630.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1632.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1637.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1639.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1640.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1641.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1642.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1644.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1645.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1646.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1652.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1653.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1654.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1655.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1657.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1661.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1663.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1667.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_167.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_1672.xml
# ==================================================================================================================
# ...
# Processing File:  corpus/citations_class\06_519.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_52.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_520.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_522.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_524.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_526.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_527.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_536.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_538.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_539.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_540.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_55.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_555.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_556.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_559.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_56.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_57.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_571.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_573.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_574.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_575.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_58.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_582.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_584.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_587.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_588.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_589.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_590.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_591.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_592.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_598.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_60.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_600.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_601.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_603.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_606.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_607.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_609.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_610.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_611.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_613.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_616.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_617.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_618.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_622.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_623.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_624.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_625.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_626.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_627.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_63.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_630.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_631.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_632.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_633.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_635.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_636.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_639.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_640.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_641.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_642.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_643.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_644.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_647.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_648.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_649.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_650.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_651.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_652.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_653.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_655.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_659.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_660.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_661.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_662.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_663.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_668.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_670.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_671.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_675.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_679.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_68.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_682.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_684.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_685.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_693.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_695.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_696.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_699.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_7.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_700.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_705.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_706.xml
# ==================================================================================================================
# Processing File:  corpus/citations_class\06_708.xml
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %% [markdown]
# <h2>Extract Labels and Sentences into Separate Txt Files</h2>

# %%
# Call Function to Separate Labels and Sentences into Separate text Files
create_labels_text_file("output.txt", "training_data_legal.txt","training_label_legal.txt")

# %% [markdown]
# <h2>Create TF-IDFVector from Training File</h2>

# %%
# Load an instance of the TF-IDF Vectorizer
vectorizer = TfidfVectorizer(stop_words='english')
#Form TF Vectors from the training sentences
vectorized_data = vectorizer.fit_transform(read_file("training_data_legal.txt"))
#The labels are read from the training Labels file
corpus_labels=read_file("training_label_legal.txt")

# %%
# See the shape of the TF Matrix
print('Shape of TF-IDF Vector: ',vectorized_data.shape)
# Out:
# Shape of TF-IDF Vector:  (25256, 37949)

# %% [markdown]
# <h2> Separate into Training and Test Sets</h2>

# %%
#Calculate the No of Docs in the Dataset and multiply by 0.8 training set size
size=int(vectorized_data.shape[0]*.8)

# %%
#separate Training and Test Sets by Size
train_data=vectorized_data[:size,:]
test_data=vectorized_data[size:,:]
train_labels=corpus_labels[:size]
test_labels=corpus_labels[size:]

# %%
#Print shapes of all Datasets
print('Shape of Training Data: ',train_data.shape)
print('Shape of Test Data: ',test_data.shape)
print('Size of Training Labels: ',len(train_labels))
print('Size of Test Labels: ',len(test_labels))
# Out:
# Shape of Training Data:  (20204, 37949)
# Shape of Test Data:  (5052, 37949)
# Size of Training Labels:  20204
# Size of Test Labels:  5052

# %% [markdown]
# # NAIVE BAYES CLASSIFIER

# %%
#Get an Instance of the NB Classifier
legal_nbc=MultinomialNB()
#Train NB Classifier on training data and labels
legal_nbc.fit(X=train_data,y=train_labels)
#Make Predictions on Test Data
legal_predict=legal_nbc.predict(test_data)

# %% [markdown]
# <h3> Model Evaluation</h3>

# %%
print('Micro F1 Score : ',f1_score(y_true=test_labels, y_pred = legal_predict, average='micro'))
print('Macro F1 Score : ',f1_score(y_true=test_labels, y_pred = legal_predict, average='macro'))
print('Accuracy : ',accuracy_score(y_true=test_labels, y_pred = legal_predict))
# Out:
# Micro F1 Score :  0.48673792557403006
# C:\Users\dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Macro F1 Score :  0.04142795574610758
# Accuracy :  0.48673792557403006

# %%
nb_conf_matrix=confusion_matrix(test_labels,legal_predict)
plot_confusion_matrix(cm           = nb_conf_matrix, 
                      normalize    = False,
                      target_names = set(test_labels),
                      title        = "Naive Bayes Confusion Matrix")

# %% [markdown]
# # ROCCHIO

# %%
#Get an Instance of the Rocchhio Classifier
legal_rocchio=NearestCentroid()
#Train Rocchhio Classifier on training data and labels
legal_rocchio.fit(X=train_data,y=train_labels)
#Make Predictions on Test Data
legal_roc_predict=legal_rocchio.predict(test_data)

# %% [markdown]
# <h3> Model Evaluation</h3>

# %%
print('Micro F1 Score : ',f1_score(y_true=test_labels, y_pred = legal_roc_predict, average='micro'))
print('Macro F1 Score : ',f1_score(y_true=test_labels, y_pred = legal_roc_predict, average='macro'))
print('Accuracy : ',accuracy_score(y_true=test_labels, y_pred = legal_roc_predict))
# Out:
# Micro F1 Score :  0.2717735550277118
# C:\Users\dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# C:\Users\dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1137: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)
# Macro F1 Score :  0.12504740532477887
# Accuracy :  0.2717735550277118

# %% [markdown]
# <h3>Confusion Matrix</h3>

# %%
roc_conf_matrix=confusion_matrix(test_labels,legal_roc_predict)
plot_confusion_matrix(cm           = roc_conf_matrix, 
                      normalize    = False,
                      target_names = set(test_labels),
                      title        = "Rocchhio Confusion Matrix")

# %% [markdown]
# # kNN k =5

# %%
#Get an Instance of the kNN Classifier
legal_knn5=KNeighborsClassifier(n_neighbors=5)
#Train kNN Classifier on training data and labels
legal_knn5.fit(X=train_data,y=train_labels)
#Make Predictions on Test Data
legal_knn5_predict=legal_knn5.predict(test_data)

# %% [markdown]
# <h3> Model Evaluation</h3>

# %%
print('Micro F1 Score : ',f1_score(y_true=test_labels, y_pred = legal_knn5_predict, average='micro'))
print('Macro F1 Score : ',f1_score(y_true=test_labels, y_pred = legal_knn5_predict, average='macro'))
print('Accuracy : ',accuracy_score(y_true=test_labels, y_pred = legal_knn5_predict))
# Out:
# Micro F1 Score :  0.37826603325415675
# C:\Users\dell\Anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Macro F1 Score :  0.09956861922492265
# Accuracy :  0.37826603325415675

# %%
knn5_conf_matrix=confusion_matrix(test_labels,legal_knn5_predict)
plot_confusion_matrix(cm           = knn5_conf_matrix, 
                      normalize    = False,
                      target_names = set(test_labels),
                      title        = "knn (5) Confusion Matrix")
